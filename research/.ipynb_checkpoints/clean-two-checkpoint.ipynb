# %%
import pandas as pd
import numpy as np
import pandas_datareader.data as pdr
import datetime



econ_data = 'finaltoclean.csv'
df= pd.read_csv(econ_data) #, dtype = {'Date': str})
#print(df)

# %%
new_header = df.iloc[0] #grab first row for the header
df1 = df[1:] # take data less the header row
df1.columns = new_header

list(df1.columns) # checking
# Out:
# ['date',
#  'Govt stringency',
#  'VaxFull',
#  'Total Covid',
#  'New Cases',
#  'New Cases Per Million',
#  'New Deaths',
#  'New Deaths Per Million',
#  'Michigan overall consumer sentiment',
#  'Michigan Sentiment Expected Conditions',
#  'Michigan Sentiment Current Conditions',
#  'Conference Board Overall Consumer Confidence',
#  'Conference Board Consumer Confidence in Expected Conditions',
#  'Conference Board Consumer Confidence in Current Conditions',
#  'ISM Manufacturing',
#  'ISM nonmanufacuring',
#  'PSAVERT',
#  'REAL GDP(Q)']

# %%
df2 = df1.rename(columns={'Govt stringency':'govt_str','Total Covid':'tot_covid','New Cases':'new_cases','New Cases Per Million':'new_cases-pm',
                          'New Deaths':'new_deaths','New Deaths Per Million':'new_deaths-pm',
                          'Michigan overall consumer sentiment':'over_mcsi', 'Michigan Sentiment Expected Conditions':'exp_mcsi',
                          'Michigan Sentiment Current Conditions':'cur_mcsi', 'Conference Board Overall Consumer Confidence':'over_cci',
                          'Conference Board Consumer Confidence in Expected Conditions':'exp_cci',
                          'Conference Board Consumer Confidence in Current Conditions':'cur_cci', 'ISM Manufacturing':'manu_ism',
                          'ISM nonmanufacuring':'nonmanu_ism'})
df2
# Out:
# 0         date govt_str VaxFull tot_covid new_cases new_cases-pm new_deaths  \
# 1     1/1/1967        0       0         0         0            0          0
# 2     2/1/1967        0       0         0         0            0          0
# 3     3/1/1967        0       0         0         0            0          0
# 4     4/1/1967        0       0         0         0            0          0
# 5     5/1/1967        0       0         0         0            0          0
# ...        ...      ...     ...       ...       ...          ...        ...
# 1418       NaN      NaN     NaN       NaN       NaN          NaN        NaN
# 1419       NaN      NaN     NaN       NaN       NaN          NaN        NaN
# 1420       NaN      NaN     NaN       NaN       NaN          NaN        NaN
# 1421       NaN      NaN     NaN       NaN       NaN          NaN        NaN
# 1422       NaN      NaN     NaN       NaN       NaN          NaN        NaN
#
# ...

# %%
df3 = df2.replace(r'^\s*$', np.nan, regex=True)
df3
# Out:
# 0         date govt_str VaxFull tot_covid new_cases new_cases-pm new_deaths  \
# 1     1/1/1967        0       0         0         0            0          0
# 2     2/1/1967        0       0         0         0            0          0
# 3     3/1/1967        0       0         0         0            0          0
# 4     4/1/1967        0       0         0         0            0          0
# 5     5/1/1967        0       0         0         0            0          0
# ...        ...      ...     ...       ...       ...          ...        ...
# 1418       NaN      NaN     NaN       NaN       NaN          NaN        NaN
# 1419       NaN      NaN     NaN       NaN       NaN          NaN        NaN
# 1420       NaN      NaN     NaN       NaN       NaN          NaN        NaN
# 1421       NaN      NaN     NaN       NaN       NaN          NaN        NaN
# 1422       NaN      NaN     NaN       NaN       NaN          NaN        NaN
#
# ...

# %%
#df4 = df3.to_csv('clean_reg.csv', encoding='utf-8', index=False)

# %%
import statsmodels.api as sm
import pandas
from patsy import dmatrices

# %%
df4 = pd.read_csv('clean_reg.csv') #, dtype = {'Date': str})

# %%
vars = ['tot_covid','cur_mcsi','exp_mcsi','PSAVERT','new_deaths','cur_cci']
df4 = df4[vars]

# %%
df4[-5:]
# Out:
#       tot_covid  cur_mcsi  exp_mcsi  PSAVERT  new_deaths  cur_cci
# 1417        NaN       NaN       NaN      NaN         NaN      NaN
# 1418        NaN       NaN       NaN      NaN         NaN      NaN
# 1419        NaN       NaN       NaN      NaN         NaN      NaN
# 1420        NaN       NaN       NaN      NaN         NaN      NaN
# 1421        NaN       NaN       NaN      NaN         NaN      NaN

# %%
y, X = dmatrices('cur_cci ~ tot_covid + cur_mcsi + exp_msci + PSAVERT + new_deaths + cur_cci', data=df, return_type='dataframe')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/compat.py:36, in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35 try:
# ---> 36     return f(*args, **kwargs)
#      37 except Exception as e:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/patsy/eval.py:165, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     164 code = compile(expr, source_name, "eval", self.flags, False)
# --> 165 return eval(code, {}, VarLookupDict([inner_namespace]
#     166                                     + self._namespaces))
#
# File <string>:1, in <module>
#
# NameError: name 'tot_covid' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ...
