# %%
import pandas as pd
import numpy as np

one = 'Money_Stringency_Vax_data.csv'
df1 = pd.read_csv(one)
print(df1)
# Out:
#       See Col      AR and AX     Unnamed: 2  Unnamed: 3   Unnamed: 4  \
# 0    iso_code      continent       location        date  total_cases
# 1         USA  North America  United States   1/22/2020            1
# 2         USA  North America  United States   1/23/2020            1
# 3         USA  North America  United States   1/24/2020            2
# 4         USA  North America  United States   1/25/2020            2
# ..        ...            ...            ...         ...          ...
# 995       USA  North America  United States  10/12/2022     96847991
# 996       USA  North America  United States  10/13/2022     96912054
# 997       USA  North America  United States  10/14/2022     96940217
# 998       USA  North America  United States  10/15/2022     96945785
# 999       USA  North America  United States  10/16/2022     96952191
#
#     Unnamed: 5          Unnamed: 6    Unnamed: 7  Unnamed: 8  \
# 0    new_cases  new_cases_smoothed  total_deaths  new_deaths
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 68 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   See Col      1000 non-null   object
#  1   AR and AX    1000 non-null   object
#  2   Unnamed: 2   1000 non-null   object
#  3   Unnamed: 3   1000 non-null   object
#  4   Unnamed: 4   1000 non-null   object
#  5   Unnamed: 5   999 non-null    object
#  6   Unnamed: 6   994 non-null    object
#  7   Unnamed: 7   962 non-null    object
#  8   Unnamed: 8   960 non-null    object
#  9   Unnamed: 9   955 non-null    object
#  10  Unnamed: 10  1000 non-null   object
#  11  Unnamed: 11  999 non-null    object
#  12  Unnamed: 12  994 non-null    object
#  13  Unnamed: 13  962 non-null    object
#  14  Unnamed: 14  960 non-null    object
#  15  Unnamed: 15  955 non-null    object
#  16  Unnamed: 16  942 non-null    object
#  17  Unnamed: 17  824 non-null    object
# ...

# %%
df.head(30)
# Out:
#          DATE  level_1      0
# 0  1952-11-01  UMCSENT   86.2
# 1  1953-02-01  UMCSENT   90.7
# 2  1953-08-01  UMCSENT   80.8
# 3  1953-11-01  UMCSENT   80.7
# 4  1954-02-01  UMCSENT   82.0
# 5  1954-05-01  UMCSENT   82.9
# 6  1954-11-01  UMCSENT   87.0
# 7  1955-02-01  UMCSENT   95.9
# 8  1955-05-01  UMCSENT   99.1
# 9  1955-11-01  UMCSENT   99.7
# 10 1956-05-01  UMCSENT   98.2
# 11 1956-08-01  UMCSENT   99.9
# 12 1956-11-01  UMCSENT  100.2
# 13 1957-05-01  UMCSENT   92.9
# 14 1957-11-01  UMCSENT   83.7
# 15 1958-02-01  UMCSENT   78.5
# 16 1958-05-01  UMCSENT   80.9
# 17 1958-11-01  UMCSENT   90.8
# 18 1959-05-01  UMCSENT   95.3
# 19 1959-11-01  UMCSENT   93.8
# 20 1960-02-01  UMCSENT  100.0
# 21 1960-05-01  UMCSENT   93.3
# 22 1960-08-01  UMCSENT   97.2
# 23 1960-11-01  UMCSENT   90.1
# 24 1961-02-01  UMCSENT   91.6
# 25 1961-05-01  UMCSENT   92.5
# 26 1961-08-01  UMCSENT   99.2
# 27 1961-11-01  UMCSENT   93.0
# 28 1962-02-01  UMCSENT   99.9
# 29 1962-05-01  UMCSENT   95.4

# %%
#Now, goinng to start deleting rows that have a lot of nulls. For examples when this was ran, df.info(file), unnamed: 60 has one non-null

# for col_name in df.columns: 
#    print(col_name)
#df.info()
df.head(60)
# Out:
#          DATE  level_1      0
# 0  1952-11-01  UMCSENT   86.2
# 1  1953-02-01  UMCSENT   90.7
# 2  1953-08-01  UMCSENT   80.8
# 3  1953-11-01  UMCSENT   80.7
# 4  1954-02-01  UMCSENT   82.0
# 5  1954-05-01  UMCSENT   82.9
# 6  1954-11-01  UMCSENT   87.0
# 7  1955-02-01  UMCSENT   95.9
# 8  1955-05-01  UMCSENT   99.1
# 9  1955-11-01  UMCSENT   99.7
# 10 1956-05-01  UMCSENT   98.2
# 11 1956-08-01  UMCSENT   99.9
# 12 1956-11-01  UMCSENT  100.2
# 13 1957-05-01  UMCSENT   92.9
# 14 1957-11-01  UMCSENT   83.7
# 15 1958-02-01  UMCSENT   78.5
# 16 1958-05-01  UMCSENT   80.9
# 17 1958-11-01  UMCSENT   90.8
# 18 1959-05-01  UMCSENT   95.3
# 19 1959-11-01  UMCSENT   93.8
# 20 1960-02-01  UMCSENT  100.0
# 21 1960-05-01  UMCSENT   93.3
# 22 1960-08-01  UMCSENT   97.2
# 23 1960-11-01  UMCSENT   90.1
# 24 1961-02-01  UMCSENT   91.6
# 25 1961-05-01  UMCSENT   92.5
# 26 1961-08-01  UMCSENT   99.2
# 27 1961-11-01  UMCSENT   93.0
# 28 1962-02-01  UMCSENT   99.9
# 29 1962-05-01  UMCSENT   95.4
# ...

# %% [markdown]
# Dont run, confirming no unique values in Unnamed:20 annd Unnamed:21

# %%
for col in list(df1):
    print(col)
    print(df1[col].unique())
# Out:
# See Col
# ['iso_code' 'USA']
# AR and AX
# ['continent' 'North America']
# Unnamed: 2
# ['location' 'United States']
# Unnamed: 3
# ['date' '1/22/2020' '1/23/2020' '1/24/2020' '1/25/2020' '1/26/2020'
#  '1/27/2020' '1/28/2020' '1/29/2020' '1/30/2020' '1/31/2020' '2/1/2020'
#  '2/2/2020' '2/3/2020' '2/4/2020' '2/5/2020' '2/6/2020' '2/7/2020'
#  '2/8/2020' '2/9/2020' '2/10/2020' '2/11/2020' '2/12/2020' '2/13/2020'
#  '2/14/2020' '2/15/2020' '2/16/2020' '2/17/2020' '2/18/2020' '2/19/2020'
#  '2/20/2020' '2/21/2020' '2/22/2020' '2/23/2020' '2/24/2020' '2/25/2020'
#  '2/26/2020' '2/27/2020' '2/28/2020' '2/29/2020' '3/1/2020' '3/2/2020'
#  '3/3/2020' '3/4/2020' '3/5/2020' '3/6/2020' '3/7/2020' '3/8/2020'
#  '3/9/2020' '3/10/2020' '3/11/2020' '3/12/2020' '3/13/2020' '3/14/2020'
#  '3/15/2020' '3/16/2020' '3/17/2020' '3/18/2020' '3/19/2020' '3/20/2020'
#  '3/21/2020' '3/22/2020' '3/23/2020' '3/24/2020' '3/25/2020' '3/26/2020'
# ...

# %% [markdown]
# Deletiing more columns and checking with listing columns headers

# %%
df1.drop('Unnamed: 21',axis=1,inplace=True)
df1.drop('Unnamed: 22',axis=1,inplace=True)
df1.drop('Unnamed: 60',axis=1,inplace=True)

# %%
list(df1.columns)
# Out:
# ['See Col',
#  'AR and AX',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51',
#  'Unnamed: 52',
#  'Unnamed: 53',
#  'Unnamed: 54',
#  'Unnamed: 55',
#  'Unnamed: 56',
#  'Unnamed: 57',
# ...

# %%
print([col for col in df])
# Out:
# ['DATE', 'level_1', 0]

# %%
df1.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1.describe()
# Out:
#        See Col      AR and AX     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# count     1000           1000           1000       1000       1000        999
# unique       2              2              2       1000        973        965
# top        USA  North America  United States       date         14          0
# freq       999            999            999          1          8         27
#
#        Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 57  \
# count         994        962        960        955  ...        1000
# unique        969        961        780        913  ...           2
# top         0.286          1        475    754.714  ...       10.79
# freq           13          2          5          3  ...         999
#
#        Unnamed: 58 Unnamed: 59 Unnamed: 61 Unnamed: 62 Unnamed: 63  \
# count         1000        1000        1000        1000        1000
# unique           2           2           2           2           2
# ...

# %%
new_header = df1.iloc[0] #grab the first row for the header
df1 = df1[:1] #take the data less the header row
df1.columns = new_header

# %%
df1.describe()
# Out:
# 0       iso_code  continent  location  date  total_cases  new_cases  \
# count          1          1         1     1            1          1
# unique         1          1         1     1            1          1
# top     iso_code  continent  location  date  total_cases  new_cases
# freq           1          1         1     1            1          1
#
# 0       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# count                    1             1           1                    1
# unique                   1             1           1                    1
# top     new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed
# freq                     1             1           1                    1
#
# 0       ...  diabetes_prevalence  female_smokers  male_smokers  \
# count   ...                    1               1             1
# unique  ...                    1               1             1
# ...

# %%
df1.drop('date_vac',axis=1,inplace=True)# dropping vac date column becuase it is the same as the first date column
df1.drop('iso_code',axis=1,inplace=True)
df1.drop('continent',axis=1,inplace=True)
df1.drop('location',axis=1,inplace=True)

# %%
import pandas_datareader.data as pdr

import datetime

start = datetime.datetime(1900,1,1)   
end = datetime.datetime.now()

df = pdr.DataReader('UMCSENT', start = start, end = end, data_source='fred') # ['UMCSENT'] 
df = df.stack().reset_index()
print(df)
# df = df.to_csv('UMCSENT_historical.csv', encoding='utf-8', index=False)
# Out:
#           DATE  level_1     0
# 0   1952-11-01  UMCSENT  86.2
# 1   1953-02-01  UMCSENT  90.7
# 2   1953-08-01  UMCSENT  80.8
# 3   1953-11-01  UMCSENT  80.7
# 4   1954-02-01  UMCSENT  82.0
# ..         ...      ...   ...
# 624 2022-05-01  UMCSENT  58.4
# 625 2022-06-01  UMCSENT  50.0
# 626 2022-07-01  UMCSENT  51.5
# 627 2022-08-01  UMCSENT  58.2
# 628 2022-09-01  UMCSENT  58.6
#
# [629 rows x 3 columns]

# %%
from datetime import datetime
import datetime

# %%
display(df1,df)

#df = df.rename(columns={'DATE':'date'})
#df
# Out:
# 0  date  total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0  date  total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths
#
# 0  new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# 0  new_deaths_smoothed  total_cases_per_million  new_cases_per_million
#
# 0  new_cases_smoothed_per_million  ...  diabetes_prevalence  female_smokers  \
# 0  new_cases_smoothed_per_million  ...  diabetes_prevalence  female_smokers
#
# 0  male_smokers  hospital_beds_per_thousand  life_expectancy  \
# 0  male_smokers  hospital_beds_per_thousand  life_expectancy
#
# 0  human_development_index  excess_mortality_cumulative_absolute  \
# 0  human_development_index  excess_mortality_cumulative_absolute
#
# 0  excess_mortality_cumulative  excess_mortality  \
# 0  excess_mortality_cumulative  excess_mortality
#
# 0  excess_mortality_cumulative_per_million
# 0  excess_mortality_cumulative_per_million
#
# [1 rows x 61 columns]
# ...

# %%
#new_header = df1.iloc[0] # grab the first row for the header
#df1 = df1[1:] # delete first row

# %%
df2.dtypes
#file_one.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [79], in <cell line: 1>()
# ----> 1 df2.dtypes
#
# NameError: name 'df2' is not defined

# %%
x = df1.shape
y = df2.shape

print(x)
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [80], in <cell line: 2>()
#       1 x = df1.shape
# ----> 2 y = df2.shape
#       4 print(x)
#       5 print(y)
#
# NameError: name 'df2' is not defined

# %%
# NEED to horizontally merge datasets
merged_of = pd.merge(df,df1,on='date')
print(merged_of)
# Out:
#          date iso_code      continent       location total_cases new_cases  \
# 0  2020-02-01      USA  North America  United States           8         0
# 1  2020-03-01      USA  North America  United States          32         7
# 2  2020-04-01      USA  North America  United States      227898     35819
# 3  2020-05-01      USA  North America  United States     1115889     34850
# 4  2020-06-01      USA  North America  United States     1808811     17858
# 5  2020-07-01      USA  North America  United States     2698251     49346
# 6  2020-08-01      USA  North America  United States     4607030     57410
# 7  2020-09-01      USA  North America  United States     6089750     41970
# 8  2020-10-01      USA  North America  United States     7294099     46383
# 9  2020-11-01      USA  North America  United States     9255213     78092
# 10 2020-12-01      USA  North America  United States    13867794    198704
# ...

# %%
#df.to_csv('cleaned_data_trial.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 1 to 999
# Data columns (total 65 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   iso_code                                    999 non-null    object
#  1   continent                                   999 non-null    object
#  2   location                                    999 non-null    object
#  3   date                                        999 non-null    object
#  4   total_cases                                 999 non-null    object
#  5   new_cases                                   998 non-null    object
#  6   new_cases_smoothed                          993 non-null    object
#  7   total_deaths                                961 non-null    object
#  8   new_deaths                                  959 non-null    object
#  9   new_deaths_smoothed                         954 non-null    object
# ...

# %%
# converting df 'date' column to datetime  format
#df1['date'] = pd.to_datetime(df1['date'])
#df = pd.to_datetime(df['date'], format='%M/%D/%Y')
df1.dtypes
# Out:
# 0
# iso_code                                   object
# continent                                  object
# location                                   object
# date                                       object
# total_cases                                object
#                                             ...
# human_development_index                    object
# excess_mortality_cumulative_absolute       object
# excess_mortality_cumulative                object
# excess_mortality                           object
# excess_mortality_cumulative_per_million    object
# Length: 65, dtype: object

# %%
# Rename column name by index
#df1.rename(columns={df1.columns[2]: 'date_vac'},inplace=True)
#print(df1.columns)
print(df1)
# Out:
# 0   iso_code      continent       location       date total_cases new_cases  \
# 1        USA  North America  United States 2020-01-22           1       NaN
# 2        USA  North America  United States 2020-01-23           1         0
# 3        USA  North America  United States 2020-01-24           2         1
# 4        USA  North America  United States 2020-01-25           2         0
# 5        USA  North America  United States 2020-01-26           5         3
# ..       ...            ...            ...        ...         ...       ...
# 995      USA  North America  United States 2022-10-12    96847991     64467
# 996      USA  North America  United States 2022-10-13    96912054     64063
# 997      USA  North America  United States 2022-10-14    96940217     28163
# 998      USA  North America  United States 2022-10-15    96945785      5568
# 999      USA  North America  United States 2022-10-16    96952191      6406
#
# ...
